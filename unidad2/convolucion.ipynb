# %% [markdown]
# Nombre:Franz Abdel Caballero Condori

# %% [markdown]
# Convoluvion

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('D:\Franz Caballero\Procesamiento de imagenes\Actividades\Ejercicios python\imagenes\original\gato.jpeg',0)
mascara=np.array([[0,-1,0,],
                  [1,5,-1,],
                  [0,1,0,]])
img_final=cv2.filter2D(img,-1,mascara)
plt.subplot(121)
plt.title('Imagen Original')
plt.axis('off')
plt.imshow(img,cmap='gray')

plt.subplot(122)
plt.title('Imagen con mascara')
plt.axis('off')
plt.imshow(img_final,cmap='gray')

plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\F'
# <>:4: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\Estudiante\AppData\Local\Temp\ipykernel_19916\2710102986.py:4: SyntaxWarning: invalid escape sequence '\F'
#   img=cv2.imread('D:\Franz Caballero\Procesamiento de imagenes\Actividades\Ejercicios python\imagenes\original\gato.jpeg')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('D:\Franz Caballero\Procesamiento de imagenes\Actividades\Ejercicios python\imagenes\original\gato.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
kernel5x5=np.ones((5,5),np.float32)/25 #suavisado
img_suavisado1=cv2.filter2D(img,-1,kernel5x5)
kernel7x7=np.ones((7,7),np.float32)/49 #suavisado
img_suavisado2=cv2.filter2D(img,-1,kernel7x7)
plt.figure(figsize=(10,5))
plt.subplot(131)
plt.title('Imagen Original')
plt.axis('off')
plt.imshow(img)

plt.subplot(132)
plt.title('Imagen con mascara 1')
plt.axis('off')
plt.imshow(img_suavisado1,cmap='gray')

plt.subplot(133)
plt.title('Imagen con mascara 2')
plt.axis('off')
plt.imshow(img_suavisado2,cmap='gray')
plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\F'
# <>:4: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\Estudiante\AppData\Local\Temp\ipykernel_19916\2968580445.py:4: SyntaxWarning: invalid escape sequence '\F'
#   img=cv2.imread('D:\Franz Caballero\Procesamiento de imagenes\Actividades\Ejercicios python\imagenes\original\gato.jpeg')

# %% [markdown]
# Trabajo

# %% [markdown]
# Funciones filtros

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def Enfoque(img):
    mascara=np.array([[0,-1,0,],
                      [-1,5,-1,],
                      [0,-1,0,]])
    img_final=cv2.filter2D(img,-1,mascara)
    return img_final
def Decenfoque(img):
    mascara=np.array([[1,1,1,],
                  [1,1,1,],
                  [1,1,1,]])
    img_final=cv2.filter2D(img,-1,mascara)
    return img_final
def Realce_bordes(img):
    mascara=np.array([[0,0,0,],
                  [-1,1,0,],
                  [0,0,0,]])
    img_final=cv2.filter2D(img,-1,mascara)
    return img_final
def Repajado(img):
    mascara=np.array([[-2,-1,0,],
                  [-1,1,1,],
                  [0,1,2,]])
    img_final=cv2.filter2D(img,-1,mascara)
    return img_final
def DetencionBordes(img):
    mascara=np.array([[0,-1,0,],
                  [-1,5,-1,],
                  [0,-1,0,]])
    img_final=cv2.filter2D(img,-1,mascara)
    return img_final
def Sobel(img):
    mascara=np.array([[-1,0,1,],
                  [-2,0,2,],
                  [-1,0,1,]])
    img_final=cv2.filter2D(img,-1,mascara)
    return img_final
def Sharpen(img):
    mascara=np.array([[1,-2,1,],
                  [-2,5,-2,],
                  [1,-2,1,]])
    img_final=cv2.filter2D(img,-1,mascara)
    return img_final
def FiltroNorte(img):
    mascara=np.array([[1,1,1,],
                  [1,-2,1,],
                  [-1,-1,-1,]])
    img_final=cv2.filter2D(img,-1,mascara)
    return img_final
def FiltroEste(img):
    mascara=np.array([[-1,1,1,],
                  [-1,-2,1,],
                  [-1,1,1,]])
    img_final=cv2.filter2D(img,-1,mascara)
    return img_final
def Gauss(img):
    mascara=np.array([[1,2,3,1,1],
                  [2,7,11,7,2],
                  [3,11,17,11,3],
                  [2,7,11,7,1],
                  [1,2,3,2,1],])
    img_final=cv2.filter2D(img,-1,mascara)
    return img_final
img=cv2.imread(r'D:\Franz Caballero\Procesamiento de imagenes\Actividades\Ejercicios python\imagenes\original\flores.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
enfoque=Enfoque(img)
decenfoque=Decenfoque(img)
realce=Realce_bordes(img)
repajado=Repajado(img)
detencion=DetencionBordes(img)
sobel=Sobel(img)
sharpen=Sharpen(img)
norte=FiltroNorte(img)
este=FiltroEste(img)
gauss=Gauss(img)
filtros=[enfoque,decenfoque,realce,repajado,detencion,sobel,sharpen,norte,este,gauss]
plt.figure(figsize=(25,15))
for i, f in enumerate(filtros):
    plt.subplot(2, 5, i+1)  
    plt.title(f'Filtro {i+1}')
    plt.axis('off')
    plt.imshow(f)
plt.show()
