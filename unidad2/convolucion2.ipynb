# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def convolucion_media_horizontal(imagen,tama_kernel):
    kernel=np.ones((1,tama_kernel),np.float32)/tama_kernel
    img_final=cv2.filter2D(imagen,-1,kernel)
    return img_final
img=cv2.imread(r'imagenes/original/distoricion horizontal 2.jpg')
gris=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

imgres=convolucion_media_horizontal(gris,5)

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.title("original")
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

plt.subplot(122)
plt.title("filtro")
plt.imshow(imgres,cmap="gray")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 9
#       7     return img_final
#       8 img=cv2.imread(r'imagenes/original/distoricion horizontal 2.jpg')
# ----> 9 gris=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#      11 imgres=convolucion_media_horizontal(gris,5)
#      13 plt.figure(figsize=(15,5))
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def convolucion_media_horizontal(imagen,tama_kernel):
    kernel=np.ones((1,tama_kernel),np.float32)/tama_kernel
    img_final=cv2.filter2D(imagen,-1,kernel)
    return img_final
img=cv2.imread(r'imagenes/original/distoricion horizontal.jpg')
rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
imgresR=convolucion_media_horizontal(rgb[:,:,0],25)
imgresG=convolucion_media_horizontal(rgb[:,:,1],25)
imgresB=convolucion_media_horizontal(rgb[:,:,2],25)

plt.figure(figsize=(25,10))
plt.subplot(141)
plt.title("original")
plt.axis("off")
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

plt.subplot(142)
plt.title("filtro R")
plt.axis("off")
plt.imshow(imgresR,cmap="gray")

plt.subplot(143)
plt.title("filtro G")
plt.axis("off")
plt.imshow(imgresG,cmap="gray")

plt.subplot(144)
plt.title("filtro B")
plt.imshow(imgresB,cmap="gray")

plt.show()

# %% [markdown]
# imagen ruido

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img_ruido=np.random.randint(0,256,size=(256,256),dtype=np.uint8)
img_blur=cv2.GaussianBlur(img_ruido,(5,5),0)
plt.figure(figsize=(25,10))
plt.subplot(121)
plt.title("original")
plt.axis("off")
plt.imshow(cv2.cvtColor(img_ruido,cv2.COLOR_BGR2RGB))

plt.subplot(122)
plt.title("filtro blur")
plt.axis("off")
plt.imshow(img_blur,cmap="gray")
plt.show()

# %% [markdown]
# forma vertical

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def convolucion_media_vertical(imagen,tama_kernel):
    kernel=np.ones((tama_kernel,1),np.float32)/tama_kernel
    img_final=cv2.filter2D(imagen,-1,kernel)
    return img_final
img=cv2.imread(r'imagenes/original/distoricion.jpg')
rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
imgresR=convolucion_media_vertical(rgb[:,:,0],50)
imgresG=convolucion_media_vertical(rgb[:,:,1],50)
imgresB=convolucion_media_vertical(rgb[:,:,2],50)

plt.figure(figsize=(25,10))
plt.subplot(141)
plt.title("original")
plt.axis("off")
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

plt.subplot(142)
plt.title("filtro R")
plt.axis("off")
plt.imshow(imgresR,cmap="gray")

plt.subplot(143)
plt.title("filtro G")
plt.axis("off")
plt.imshow(imgresG,cmap="gray")

plt.subplot(144)
plt.title("filtro B")
plt.imshow(imgresB,cmap="gray")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 9
#       7     return img_final
#       8 img=cv2.imread(r'imagenes/original/distoricion.jpg')
# ----> 9 rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#      10 imgresR=convolucion_media_vertical(rgb[:,:,0],50)
#      11 imgresG=convolucion_media_vertical(rgb[:,:,1],50)
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# diagonal

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def convolucion_media_diagonal(imagen,tama_kernel):
    kernel = np.ones((tama_kernel, tama_kernel), np.float32) / (tama_kernel * tama_kernel)
    img_final=cv2.filter2D(imagen,-1,kernel)
    return img_final
img=cv2.imread(r'imagenes/img distorcion/diagonal2.jpg')
rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
imgresR=convolucion_media_diagonal(rgb[:,:,0],174)
imgresG=convolucion_media_diagonal(rgb[:,:,1],174)
imgresB=convolucion_media_diagonal(rgb[:,:,2],174)

plt.figure(figsize=(25,10))
plt.subplot(141)
plt.title("original")
plt.axis("off")
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

plt.subplot(142)
plt.title("filtro R")
plt.axis("off")
plt.imshow(imgresR,cmap="gray")

plt.subplot(143)
plt.title("filtro G")
plt.axis("off")
plt.imshow(imgresG,cmap="gray")

plt.subplot(144)
plt.title("filtro B")
plt.imshow(imgresB,cmap="gray")

plt.show()

# %% [markdown]
# aliasing

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def filtro_gaussiano(imagen, kernel_size):
    return cv2.GaussianBlur(imagen, (kernel_size, kernel_size), 0)

img=cv2.imread(r'imagenes/img distorcion/dis2.jfif')
rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
imgresR=filtro_gaussiano(rgb[:,:,0],15)
imgresG=filtro_gaussiano(rgb[:,:,1],15)
imgresB=filtro_gaussiano(rgb[:,:,2],15)

plt.figure(figsize=(25,10))
plt.subplot(141)
plt.title("original")
plt.axis("off")
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

plt.subplot(142)
plt.title("filtro R")
plt.axis("off")
plt.imshow(imgresR,cmap="gray")

plt.subplot(143)
plt.title("filtro G")
plt.axis("off")
plt.imshow(imgresG,cmap="gray")

plt.subplot(144)
plt.title("filtro B")
plt.axis("off")
plt.imshow(imgresB,cmap="gray")

plt.show()

# %% [markdown]
# Moire

# %%
import cv2
import matplotlib.pyplot as plt
img1 = cv2.imread('imagenes/img distorcion/dis2.jfif')
plt.figure(figsize=(25,10))
count=1
img1Fix = cv2.medianBlur(img1,15)
plt.subplot(1,2,1)
plt.imshow(img1Fix)
plt.axis("off")
plt.show()
